# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnavPabby/ds1002-ncn6dt/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
plt.pie(slices, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7e6ae88104c0>,
#   <matplotlib.patches.Wedge at 0x7e6ae88103d0>,
#   <matplotlib.patches.Wedge at 0x7e6ae8810d90>,
#   <matplotlib.patches.Wedge at 0x7e6ae8811210>,
#   <matplotlib.patches.Wedge at 0x7e6ae8811690>],
#  [Text(0.9349011005821531, 0.5796205069959818, 'US'),
#   Text(-0.21125715497921718, 1.079523234798625, 'UK'),
#   Text(-0.9728300181275684, 0.5134216160524556, 'MX'),
#   Text(-0.6116935558191647, -0.9142379306117783, 'CA'),
#   Text(0.9828146941303805, -0.49403975245055637, 'JP')])

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n)
# Out:
# (array([ 22.,  90., 296., 621., 747., 694., 375., 126.,  25.,   4.]),
#  array([426.8540371 , 427.53249995, 428.21096279, 428.88942564,
#         429.56788849, 430.24635134, 430.92481419, 431.60327704,
#         432.28173988, 432.96020273, 433.63866558]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x, y)
coefficients = np.polyfit(x, y, 1)
trendline = np.poly1d(coefficients)
plt.plot(x, trendline(x))
