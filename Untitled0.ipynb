# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnavPabby/ds1002-ncn6dt/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
#get basic info about the data frame
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#first 30 records of the data frame
mock_data.head(30)
# Out:
#     id  first_name      last_name                          email       gender  \
# 0    1      Rollie     Gheerhaert      rgheerhaert0@china.com.cn         Male
# 1    2     Estella         Lailey      elailey1@wunderground.com       Female
# 2    3    Julienne          Egger        jegger2@nydailynews.com       Female
# 3    4      Horton        Birbeck              hbirbeck3@bbb.org         Male
# 4    5     Belinda        Jadczak        bjadczak4@123-reg.co.uk       Female
# 5    6      Ragnar    Shepherdson         rshepherdson5@about.me  Genderfluid
# 6    7         Erv          Vanne          evanne6@microsoft.com         Male
# 7    8        Chen     Fitzsimons       cfitzsimons7@plala.or.jp         Male
# 8    9      Gaspar    Cuthbertson  gcuthbertson8@stumbleupon.com         Male
# 9   10        Winn     Batcheldor         wbatcheldor9@webmd.com      Agender
# 10  11  Christiano       Goodhand       cgoodhanda@webeden.co.uk         Male
# ...

# %%
#last x number of records in the data frame, default is 5
mock_data.tail()
# Out:
#        id first_name last_name                       email  gender  age
# 995   996     Hermie   Vignaux        hvignauxrn@skype.com    Male   60
# 996   997      Bunny  Phillips  bphillipsro@macromedia.com  Female   87
# 997   998        Row     Cella    rcellarp@statcounter.com  Female   24
# 998   999       Riva  Papaccio     rpapacciorq@addthis.com  Female   71
# 999  1000       Judd    Revill           jrevillrr@ovh.net    Male   95

# %%
#pluck specific rows out of the data frame
mock_data.loc[999]
# Out:
# id                         1000
# first_name                 Judd
# last_name                Revill
# email         jrevillrr@ovh.net
# gender                     Male
# age                          95
# Name: 999, dtype: object

# %%
#get basic stats about the numerical values in the data frame
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    50.364000
# std     288.819436    28.696428
# min       1.000000     1.000000
# 25%     250.750000    24.750000
# 50%     500.500000    50.500000
# 75%     750.250000    75.000000
# max    1000.000000   100.000000

# %%
#get the columns from the data frame
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
#get the data types for the differnt columns
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
#modify the column headers
mock_data = mock_data.rename(columns={"first_name":"fname", "last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id     fname       lname                      email  gender  age
# 0   1    Rollie  Gheerhaert  rgheerhaert0@china.com.cn    Male   20
# 1   2   Estella      Lailey  elailey1@wunderground.com  Female   59
# 2   3  Julienne       Egger    jegger2@nydailynews.com  Female   65
# 3   4    Horton     Birbeck          hbirbeck3@bbb.org    Male   52
# 4   5   Belinda     Jadczak    bjadczak4@123-reg.co.uk  Female   75

# %%
#get the values from only one column
mock_data['fname']
# Out:
# 0        Rollie
# 1       Estella
# 2      Julienne
# 3        Horton
# 4       Belinda
#          ...
# 995      Hermie
# 996       Bunny
# 997         Row
# 998        Riva
# 999        Judd
# Name: fname, Length: 1000, dtype: object

# %%
#another way to get the values from only one column
mock_data.fname
# Out:
# 0        Rollie
# 1       Estella
# 2      Julienne
# 3        Horton
# 4       Belinda
#          ...
# 995      Hermie
# 996       Bunny
# 997         Row
# 998        Riva
# 999        Judd
# Name: fname, Length: 1000, dtype: object

# %%
#get the values from two columns. Requires two square brackets
mock_data[['fname','lname']]
# Out:
#         fname       lname
# 0      Rollie  Gheerhaert
# 1     Estella      Lailey
# 2    Julienne       Egger
# 3      Horton     Birbeck
# 4     Belinda     Jadczak
# ..        ...         ...
# 995    Hermie     Vignaux
# 996     Bunny    Phillips
# 997       Row       Cella
# 998      Riva    Papaccio
# 999      Judd      Revill
#
# [1000 rows x 2 columns]

# %%
#Plot the gender values on a bar graph
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
#getting the mean age for each gender
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        52.470588
# Bigender       50.727273
# Female         51.315565
# Genderfluid    60.125000
# Genderqueer    43.850000
# Male           48.927907
# Non-binary     44.538462
# Polygender     56.812500
# Name: age, dtype: float64
